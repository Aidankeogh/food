# %%
import numpy as np

n_users = 25
n_recipes = 32

authors = np.random.randint(0, n_users - 1, size=n_recipes)
ratings = np.random.randint(1, 6, size=(n_users, n_recipes))

ratings = ratings.astype(float)
ratings.ravel()[np.random.choice(ratings.size, ratings.size//2, replace=False)] = np.nan

# %%
import dask_distance 
import dask.array as da

from dask.distributed import Client
client = Client(memory_limit='8GB')
# Out:
# /Users/aidankeogh/opt/anaconda3/lib/python3.8/site-packages/distributed/node.py:151: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 62401 instead
#   warnings.warn(

# %%
import sparse
x = da.random.random((25000, 150000), chunks=(5000, 5000))
x[x < 0.99983] = 0
s = x.map_blocks(sparse.COO).compute()
s
# Out:
# <COO: shape=(25000, 150000), dtype=float64, nnz=637595, fill_value=0.0>

# %%
import time
start = time.time()
d = s.map_blocks(lambda x: x.todense(), dtype=np.ndarray).compute()
print(time.time() - start)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-865d40a8d259> in <module>
#       1 import time
#       2 start = time.time()
# ----> 3 d = s.map_blocks(lambda x: x.todense(), dtype=np.ndarray).compute()
#       4 print(time.time() - start)
#
# AttributeError: 'COO' object has no attribute 'map_blocks'

# %%
import time
start = time.time()
n = da.matmul(s, s.T)
n.compute()
print(time.time() - start)
# Out:
# 16.60005784034729

# %%
ratings
scaled_ratings = (ratings.T - np.nanmean(ratings, axis=1))/np.nanstd(ratings, axis=1).T
np.nanmean(scaled_ratings, axis=1)
# Out:
# array([ 0.12600867,  0.29151563,  0.4238517 , -0.493085  , -0.29394966,
#        -0.09939557,  0.06140401,  0.1329473 , -0.18627578,  0.31956392,
#         0.37752506,  0.09802381,  0.28486257, -0.4408008 , -0.40466311,
#        -0.08532526,  0.28700318, -0.05893703, -0.02846952, -0.23463539,
#         0.34778174,  0.05415893, -0.18259516, -0.04947513, -0.10681291,
#         0.0105371 ,  0.35452878, -0.23785417, -0.45455139,  0.10355083,
#         0.19604748, -0.04021061])

# %%
trust = np.zeros((n_users, n_users))

# %%
import pandas as pd

recipe_df = pd.read_csv("data/RAW_recipes.csv")
rating_df = pd.read_csv("data/RAW_interactions.csv")

# %%
recipe_df = recipe_df.set_index("id")

# %%
user_mean_ratings = rating_df.groupby("user_id").rating.mean()
user_std_ratings = rating_df.groupby("user_id").rating.std()
rating_df["normalized_rating"] = rating_df.apply(
    lambda row: (row.rating - user_mean_ratings[row.user_id]) / user_std_ratings[row.user_id], axis=1
)
# Out:
# <ipython-input-5-9d90d817b49f>:4: RuntimeWarning: invalid value encountered in double_scalars
#   lambda row: (row.rating - user_mean_ratings[row.user_id]) / user_std_ratings[row.user_id], axis=1

# %%
rating_df = rating_df.dropna()

# %%
recipe_df["review_mean_normalized"] = rating_df.groupby("recipe_id").normalized_rating.mean()
recipe_df["review_count"] = rating_df.groupby("recipe_id").rating.count()
recipe_df["review_mean"] = rating_df.groupby("recipe_id").rating.mean()
recipe_df = recipe_df.dropna()

# %%
def bayesian_avg(mean, count, prior=0, C=10):
    return (mean * count + prior * C) / (count + C)

prior = recipe_df.review_mean_normalized.mean()
print(prior)
recipe_df["review_bayesian_mean"] = recipe_df.apply(
    lambda row: bayesian_avg(row["review_mean_normalized"], row["review_count"], prior=prior, C=100), axis=1
)
# Out:
# -0.11125552957582048

# %%
best_recipe = recipe_df.loc[recipe_df.review_bayesian_mean.idxmax()]
print(best_recipe.description)
# Out:
# cooking the meatballs in simmering pasta sauce  will not only add so much extra flavor to the sauce the meatballs will be melt-in-your-mouth tender, you may of course oven-bake the meatballs for about 25 minutes,  --- don't be afraid to add in more parmesan cheese and a little more milk, there is no need to measure exactly, this recipe is pretty much foolproof, leftover cooked meatballs make a wonderful pizza topping just slice thinly and freeze until ready to use ----- these also make wonderful juicy burgers shaped into patties-- for more of my tried and true recipes check out my food blog at www.kittencalskitchen.com

# %%
recipe_df.sort_values("review_bayesian_mean", ascending=False).head(20)
# Out:
#                                                      name  minutes  \
# id
# 69173    kittencal s italian melt in your mouth meatballs       50
# 106251  roasted cauliflower   16 roasted cloves of garlic       40
# 39087                          creamy cajun chicken pasta       25
# 31128                             yummy crunchy apple pie       70
# 8739                                     wholly guacamole       20
# 66596                      kittencal s famous greek salad       10
# 43509                         crumb topped banana muffins       35
# 28148                     oven fried chicken chimichangas       45
# 129345  chicken scaloppine with lemon glaze   low fat ...       35
# 73825                       why i joined zaar carrot cake       65
# 107786      beth s melt in your mouth barbecue ribs  oven      195
# 221743  kittencal s best blasted rapid roast whole chi...       80
# 44232                         tomato and basil bruschetta       45
# 102274  tsr version of t g i  friday s black bean soup...       75
# 131018                             pulled pork  crock pot     1110
# 80413              homemade hamburger buns  bread machine       19
# 20616                      irish rosie s irish soda bread       70
# 90674                          denny s style french toast       22
# 102617                        kittencal s famous coleslaw     1440
# 29679   reeses squares   5 ingredients   no bake  reese s       15
#
#         contributor_id   submitted  \
# id
# 69173            89831  2003-08-20
# 106251           58104  2004-12-16
# 39087            30534  2002-09-02
# 31128            29450  2002-06-13
# 8739              7802  2001-04-09
# 66596            89831  2003-07-14
# 43509            27643  2002-10-18
# 28148             6258  2002-05-13
# 129345           89831  2005-07-11
# 73825            20371  2003-10-22
# 107786          129177  2005-01-06
# 221743           89831  2007-04-09
# 44232            50778  2002-10-25
# 102274           74652  2004-10-19
# 131018           50509  2005-07-25
# 80413            24386  2004-01-07
# 20616            15718  2002-02-25
# 90674            86072  2004-05-04
# 102617           89831  2004-10-26
# 29679            37305  2002-05-29
#
#                                                      tags  \
# id
# 69173   ['60-minutes-or-less', 'time-to-make', 'course...
# 106251  ['60-minutes-or-less', 'time-to-make', 'course...
# 39087   ['30-minutes-or-less', 'time-to-make', 'course...
# 31128   ['weeknight', 'time-to-make', 'course', 'main-...
# 8739    ['30-minutes-or-less', 'time-to-make', 'course...
# 66596   ['15-minutes-or-less', 'time-to-make', 'course...
# 43509   ['60-minutes-or-less', 'time-to-make', 'course...
# 28148   ['60-minutes-or-less', 'time-to-make', 'course...
# 129345  ['60-minutes-or-less', 'time-to-make', 'course...
# 73825   ['weeknight', 'time-to-make', 'course', 'main-...
# 107786  ['time-to-make', 'course', 'main-ingredient', ...
# 221743  ['time-to-make', 'course', 'main-ingredient', ...
# 44232   ['60-minutes-or-less', 'time-to-make', 'course...
# 102274  ['time-to-make', 'course', 'main-ingredient', ...
# 131018  ['time-to-make', 'course', 'main-ingredient', ...
# 80413   ['30-minutes-or-less', 'time-to-make', 'course...
# 20616   ['weeknight', 'time-to-make', 'course', 'cuisi...
# 90674   ['30-minutes-or-less', 'time-to-make', 'course...
# 102617  ['time-to-make', 'course', 'preparation', 'occ...
# 29679   ['15-minutes-or-less', 'time-to-make', 'course...
#
#                                                nutrition  n_steps  \
# id
# 69173     [1312.6, 129.0, 8.0, 108.0, 214.0, 174.0, 8.0]        5
# 106251          [126.9, 14.0, 11.0, 17.0, 6.0, 6.0, 3.0]        4
# 39087       [719.1, 63.0, 12.0, 34.0, 78.0, 120.0, 15.0]        4
# 31128         [360.6, 22.0, 161.0, 6.0, 5.0, 38.0, 19.0]       15
# 8739          [500.7, 68.0, 14.0, 0.0, 13.0, 32.0, 10.0]       13
# 66596         [489.7, 72.0, 23.0, 33.0, 15.0, 55.0, 4.0]        8
# 43509         [220.9, 10.0, 90.0, 12.0, 5.0, 20.0, 12.0]        9
# 28148         [353.9, 25.0, 8.0, 29.0, 37.0, 32.0, 10.0]        7
# 129345          [301.6, 14.0, 8.0, 26.0, 62.0, 9.0, 7.0]       14
# 73825       [662.1, 58.0, 224.0, 24.0, 13.0, 56.0, 25.0]       13
# 107786  [1229.3, 118.0, 194.0, 36.0, 142.0, 139.0, 19.0]       19
# 221743       [841.0, 100.0, 2.0, 12.0, 115.0, 86.0, 0.0]       10
# 44232         [232.8, 19.0, 13.0, 23.0, 11.0, 11.0, 8.0]       11
# 102274        [392.5, 12.0, 17.0, 19.0, 45.0, 7.0, 19.0]        9
# 131018        [335.1, 10.0, 72.0, 24.0, 80.0, 10.0, 8.0]       26
# 80413           [198.9, 5.0, 17.0, 7.0, 11.0, 9.0, 11.0]        9
# 20616         [211.6, 10.0, 45.0, 10.0, 9.0, 17.0, 11.0]        9
# 90674        [264.3, 16.0, 55.0, 15.0, 16.0, 27.0, 11.0]       11
# 102617             [92.9, 1.0, 67.0, 1.0, 4.0, 1.0, 7.0]       12
# 29679           [222.8, 21.0, 77.0, 4.0, 7.0, 30.0, 7.0]        6
#
#                                                     steps  \
# id
# 69173   ['mix all ingredients together in a large bowl...
# 106251  ['mix oil , rosemary , salt , pepper and garli...
# 39087   ['place chicken and cajun seasoning in a bowl ...
# 31128   ['use foil on bottom of oven rather than a coo...
# 8739    ['cut avocados in half , remove pit , and spoo...
# 66596   ['for the dressing', 'in a processor or use a ...
# 43509   ['in a large bowl , mix the flour , baking sod...
# 28148   ['mix chicken , picante sauce or salsa , cumin...
# 129345  ['in a small bowl or shallow dish whisk togeth...
# 73825   ['preheat oven to 350 degrees f', 'grease and ...
# 107786  ['preheat oven to 300 degrees f', 'line a baki...
# 221743  ['rinse the chicken inside and out well under ...
# 44232   ['whisk together chopped garlic , vinegar , sa...
# 102274  ['heat 2 tablespoons of oil in a large saucepa...
# 131018  ['slice one onion and place in crock pot', 'pu...
# 80413   ["place all ingredients , except butter , in p...
# 20616   ['combine dry ingredients together in a large ...
# 90674   ['mix together the eggs , milk , flour , sugar...
# 102617  ['in a food processor chop the cabbage into sm...
# 29679   ['combine graham crumbs , sugar and peanut but...
#
#                                               description  \
# id
# 69173   cooking the meatballs in simmering pasta sauce...
# 106251  i find it totally amazing, that children and m...
# 39087   n'awlin's style of chicken with an updated alf...
# 31128                                          great pie!
# 8739    this is a true tex-mex recipe concocted by a d...
# 66596   be prepared for the best greek salad on the pl...
# 43509             these are so good. we love the topping.
# 28148   a fast and healthier way to serve chimichangas...
# 129345  this is a wonderful lower-fat restaurant-quali...
# 73825   on october 2, 2001, i discovered the recipezaa...
# 107786  i almost didn't want to share this ribs recipe...
# 221743  blasting with high heat will shrink the skin a...
# 44232                                  my first culinary
# 102274  from www.topsecretrecipes.com i got this copyc...
# 131018  i found this pulled pork recipe years ago, and...
# 80413   you will never want to buy hamburger buns agai...
# 20616   this irish soda bread recipe was passed on to ...
# 90674   i do not remember where i got this recipe, but...
# 102617  this is the most delicious coleslaw that you w...
# 29679   these bars are extremely rich and not for peop...
#
#                                               ingredients  n_ingredients  \
# id
# 69173   ['ground beef', 'egg', 'parmesan cheese', 'bre...             10
# 106251  ['cauliflower', 'garlic cloves', 'fresh rosema...              6
# 39087   ['boneless skinless chicken breast halves', 'l...             12
# 31128   ['pastry for single-crust pie', 'sugar', 'flou...             12
# 8739    ['avocados', 'garlic cloves', 'lime', 'tomatoe...              8
# 66596   ['olive oil', 'lemon, juice of', 'dried oregan...             16
# 43509   ['flour', 'baking soda', 'baking powder', 'sal...             11
# 28148   ['picante sauce', 'ground cumin', 'dried orega...              9
# 129345  ['boneless skinless chicken breasts', 'dijon m...             13
# 73825   ['all-purpose flour', 'baking soda', 'baking p...             16
# 107786  ['pork ribs', 'light brown sugar', 'hickory sm...              7
# 221743  ['whole chicken', 'oil', 'margarine', 'lemon j...              9
# 44232   ['roma tomatoes', 'garlic', 'olive oil', 'bals...              9
# 102274  ['vegetable oil', 'white onion', 'celery', 'ca...             16
# 131018  ['pork roast', 'onions', 'ginger ale', 'barbec...              4
# 80413   ['milk', 'egg', 'butter', 'white sugar', 'salt...              7
# 20616   ['flour', 'sugar', 'baking soda', 'baking powd...              9
# 90674   ['eggs', 'whole milk', 'flour', 'sugar', 'vani...             11
# 102617  ['green cabbage', 'carrot', 'green onions', 'c...             13
# 29679   ['graham cracker crumbs', "confectioners' suga...              5
#
#         review_mean_normalized  review_count  review_mean  \
# id
# 69173                 0.268764         732.0     4.706284
# 106251                0.295571         306.0     4.748366
# 39087                 0.224818         911.0     4.563117
# 31128                 0.278085         319.0     4.733542
# 8739                  0.301005         253.0     4.754941
# 66596                 0.283527         297.0     4.760943
# 43509                 0.252595         431.0     4.728538
# 28148                 0.225830         634.0     4.675079
# 129345                0.306733         223.0     4.654709
# 73825                 0.258304         344.0     4.735465
# 107786                0.300985         220.0     4.586364
# 221743                0.289389         237.0     4.767932
# 44232                 0.328243         164.0     4.750000
# 102274                0.295515         202.0     4.747525
# 131018                0.232273         375.0     4.482667
# 80413                 0.321294         161.0     4.782609
# 20616                 0.292014         193.0     4.689119
# 90674                 0.238638         312.0     4.730769
# 102617                0.309019         169.0     4.757396
# 29679                 0.209797         458.0     4.670306
#
#         review_bayesian_mean
# id
# 69173               0.223088
# 106251              0.195368
# 39087               0.191576
# 31128               0.185164
# 8739                0.184217
# 66596               0.184086
# 43509               0.184073
# 28148               0.179906
# 129345              0.177325
# 73825               0.175070
# 107786              0.172160
# 221743              0.170503
# 44232               0.161766
# 102274              0.160823
# 131018              0.159951
# 80413               0.155566
# 20616               0.154379
# 90674               0.153713
# 102617              0.152783
# 29679               0.152261

# %%
rating_df[rating_df.user_id == 89831]
# Out:
#          user_id  recipe_id        date  rating  \
# 227        89831     225171  2007-05-29       5
# 467        89831      33096  2004-03-15       5
# 805        89831     175042  2006-07-04       5
# 1102       89831      53518  2004-07-12       5
# 1282       89831     109578  2006-11-29       5
# ...          ...        ...         ...     ...
# 1129861    89831      99870  2006-07-01       5
# 1130273    89831     200623  2006-12-20       5
# 1131189    89831      63474  2006-07-25       5
# 1131337    89831      99731  2006-08-08       5
# 1132191    89831      74778  2006-01-14       5
#
#                                                     review  normalized_rating
# 227      These were buttery rich delicious! I made thes...           0.187821
# 467      Merlot...this is the second time that I made y...           0.187821
# 805      This is a wonderful rice recipe! I doubled the...           0.187821
# 1102     Uncle Bill, I made your perogies over the week...           0.187821
# 1282     This is a great cake recipe, perfect to serve ...           0.187821
# ...                                                    ...                ...
# 1129861  I chose this for the ZWT game, it's a wonderfu...           0.187821
# 1130273  This is simple and so delicious! thanks for sh...           0.187821
# 1131189  Geema  my gazpacho-loving DS said this is a fa...           0.187821
# 1131337  Thanks for posting this great recipe Barb, I h...           0.187821
# 1132191  I made this using just pineapple and mango, I ...           0.187821
#
# [3353 rows x 6 columns]

# %%
recipe_df[recipe_df.description.str.contains("delicious recipe that will amaze your friends and family")]
# Out:
#                 name  minutes  contributor_id   submitted  \
# id
# 90880  maui ahi poke       45          140434  2004-05-07
#
#                                                     tags  \
# id
# 90880  ['60-minutes-or-less', 'time-to-make', 'course...
#
#                                      nutrition  n_steps  \
# id
# 90880  [149.0, 7.0, 2.0, 35.0, 45.0, 6.0, 0.0]        4
#
#                                                    steps  \
# id
# 90880  ['cut ahi into at least 1 / 2" cubes - set asi...
#
#                                              description  \
# id
# 90880  here is a simple delicious recipe that will am...
#
#                                              ingredients  n_ingredients  \
# id
# 90880  ['fresh ahi tuna', 'round onion', 'green onion...             10
#
#        review_mean_normalized  review_count  review_mean  review_bayesian_mean
# id
# 90880                0.413931          14.0          4.5             -0.046759

# %%
rating_df[rating_df.recipe_id == 90880]
# Out:
#          user_id  recipe_id        date  rating  \
# 360985    178220      90880  2006-05-25       5
# 360986     68460      90880  2006-06-18       5
# 360988    215829      90880  2007-08-25       4
# 360990    755811      90880  2008-09-17       4
# 360991    899881      90880  2008-11-07       5
# 360993     35848      90880  2009-01-06       5
# 360998    290012      90880  2009-07-22       5
# 361003    511799      90880  2009-12-10       5
# 361004   1471923      90880  2010-01-04       5
# 361008   2687969      90880  2013-02-11       5
# 361009   2812007      90880  2013-05-04       3
# 361011    185926      90880  2013-09-13       5
# 361014      6258      90880  2017-03-13       5
# 361015  43319826      90880  2017-06-01       2
#
#                                                    review  normalized_rating
# 360985  I served this at recent party and it was nearl...           0.559017
# 360986  This is a wonderful recipe!  My husband and I ...           0.323823
# 360988  I found this recipe (although pretty authentic...          -0.645119
# 360990  Really great recipe, but I agree with other re...           0.028603
# 360991  Great authentic recipe. Yes, to other comments...           0.749025
# 360993  Absolutely fabulous!  Be sure to use a "sushi"...           0.396784
# 360998  onolicious!!!! This is even better that shoyu ...           0.728219
# 361003  Memories of Hawaii in a dish -- I wouldn't cha...           0.447214
# 361004  My friends Loved it! But Well I have made this...           0.707107
# 361008  This was the perfect poke recipe for my cravin...           0.755929
# 361009  I always enjoy poke.  I preffer red onion just...           0.707107
# 361011  Easy and delicious.  I followed the recipe exc...           0.568775
# 361014  An excellent recipe. First time to re-create t...           0.468558
# 361015  This recipe lacks ogo seaweed, a key ingredien...           0.000000

# %%
rating_df[rating_df.user_id == 178220]
# Out:
#          user_id  recipe_id        date  rating  \
# 65391     178220      65246  2006-05-25       5
# 76182     178220      27527  2006-03-25       5
# 188320    178220      32607  2006-05-03       5
# 360985    178220      90880  2006-05-25       5
# 372411    178220      15682  2006-12-25       5
# 401856    178220     121490  2006-06-03       5
# 512246    178220     118691  2006-05-03       4
# 555835    178220      95725  2006-05-30       4
# 621923    178220       2708  2006-01-16       5
# 652261    178220     121360  2006-05-03       5
# 712945    178220      67894  2006-06-13       5
# 805486    178220      63621  2006-05-25       5
# 874504    178220     134741  2006-05-25       5
# 875077    178220     127988  2006-02-22       4
# 1043604   178220      56977  2006-06-13       4
# 1063547   178220     183319  2006-10-19       5
#
#                                                     review  normalized_rating
# 65391    Thank you for the great recipe.  I served this...           0.559017
# 76182    I just made this for our Irish Night Dinner.  ...           0.559017
# 188320   I made this tonight as part of a dinner party ...           0.559017
# 360985   I served this at recent party and it was nearl...           0.559017
# 372411   I made this for a dessert offering at a holida...           0.559017
# 401856   I just made this bread.  I can't tell you how ...           0.559017
# 512246   I made this a while back and forgot to leave f...          -1.677051
# 555835   This was quite good. Instead of basting, I add...          -1.677051
# 621923   Thanks for the quick and easy recipe.  I didn'...           0.559017
# 652261   Made this tonight.  I quadrupled the garlic (w...           0.559017
# 712945   I served this dish as part of a themed dinner ...           0.559017
# 805486   I recently served this at a party.  The dish w...           0.559017
# 874504   I served this at a party recently and it went ...           0.559017
# 875077   I ended doing this with some boneless skinless...          -1.677051
# 1043604  I made this a long time ago and hadn't reviewe...          -1.677051
# 1063547  I made this today for my literature class.  It...           0.559017

# %%
rating_df[rating_df.user_id == 290012]
# Out:
#         user_id  recipe_id        date  rating  \
# 186762   290012      57680  2006-05-26       5
# 219142   290012      15690  2010-01-04       3
# 360998   290012      90880  2009-07-22       5
# 471791   290012     137030  2010-01-06       1
# 612360   290012      53629  2009-01-13       4
# 711597   290012     213252  2009-01-15       5
#
#                                                    review  normalized_rating
# 186762  It was a heat at my little kid's birthday part...           0.728219
# 219142  Not as sweet as I would have liked it to be, b...          -0.520156
# 360998  onolicious!!!! This is even better that shoyu ...           0.728219
# 471791  This recipe was very bland. Would definitely r...          -1.768532
# 612360  I marinated boneless skinless chicken thighs f...           0.104031
# 711597  Simple, but very delicious. It was so tender. ...           0.728219

# %%
recipe_df.loc[53629]
# Out:
# name                                  caramelized lemongrass chicken thighs
# minutes                                                                 285
# contributor_id                                                        41525
# submitted                                                        2003-02-05
# tags                      ['weeknight', 'time-to-make', 'course', 'main-...
# nutrition                        [380.0, 36.0, 69.0, 61.0, 45.0, 30.0, 6.0]
# n_steps                                                                  13
# steps                     ['remove skins and extra fat from chicken', 'r...
# description               this is a recipe i came across in a cookbook i...
# ingredients               ['chicken thighs', 'lemongrass', 'garlic', 'fi...
# n_ingredients                                                             8
# review_mean_normalized                                            -0.836055
# review_count                                                            6.0
# review_mean                                                        3.666667
# review_bayesian_mean                                              -0.152282
# Name: 53629, dtype: object
